# %% [markdown]
# # Libraries

# %%
import pymongo
import pandas as pd 
import csv
import pymongo
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import warnings
import re
import pprint
import inspect
import timeit

#import talos
from keras.models import Sequential
from keras.layers import Dropout, Dense
from keras.layers import LSTM


from sklearn.metrics import mean_squared_error, r2_score
#from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import sys
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Common Functions

# %%
def  traceMsg(*inpt):
    
    nl = len(inspect.stack())
    nn=0
    going=True
    stck = []
    path = ""
    while (going and nn <= nl):
       pgm = inspect.stack()[nn][3]
       if (pgm != "<module>"):
         stck.append(pgm)
         if (pgm != "traceMsg"):
            path+=f"{pgm} <= "
       else:
          going=False
          path+=f"{pgm}"
       nn+=1
    print (f"{inpt}  from  {path} ")


def plotObPrNeuralNew(phases,yobs,ypred,yrmos,indices,nlayers,nnodes,stats):   
    monsInt = ["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
   
    
    nlen = len(yrmos)

    obsdiff = []
    prddiff = []
    mdiff = []

    nplots=0
    nphs = phases
    #ydif = yyo-yyp
    ydif = [(yobs[nn]-ypred[nn]) for nn in range(0,len(yobs))]
    
    xx = [zz for zz in range(0,len(yobs))]
    men=0
    amen=0
    for val in ydif:
        men = men + val[0]
        amen = amen + abs(val[0])
    
    men=men/len(ydif)
    amen=amen/len(ydif)
    
    fig, ax1 = plt.subplots(2)
    ax1[0].plot(xx,yobs,label="Obsv",marker="s")
    ax1[0].plot(xx,ypred,label="Pred",marker="X")
    ax1[0].legend(loc="upper left")
    ax1[0].tick_params(axis="x",direction="in")

    ax1[0].set_title(f"Observed and Predicted for Neural Network for phase shift of {nphs}")


def plotObPrNeural(phases,yobs,ypred,yrmos,indices,nlayers,nnodes,stats):   
    monsInt = ["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
   
    print("PP ",yobs)
    
    nlen = len(yrmos)
    yrmosExp = yrmos[nlen-nsplit:]
    
    meansPlot = []
    stdsPlot = []
    for lab in yrmosExp:
        mon = str(lab)
        mon = int(mon[4:6])-1
 #       mon = monsInt[mon]
        meansPlot.append(stats[mon]["mean"])
        stdsPlot.append(stats[mon]["std"])
    xticks = [0,5,12,17,23]
    xlabs = [yrmosExp[j] for j in [0,5,12,17,23]]
    obsdiff = []
    prddiff = []
    mdiff = []
 #   for nn in range(len(yobs)):
 #       obsdiff.append((yobs[nn]-meansPlot[nn])/stdsPlot[nn])
 #       prddiff.append((yobs[nn]-ypred[nn])/stdsPlot[nn])
 #       odf = abs(yobs[nn] - (meansPlot[nn]+stdsPlot[nn]))
 #       pdf = abs(yobs[nn]-ypred[nn])
 #       mdiff.append(odf-pdf)
    nplots=0
    nphs = phases
    #ydif = yyo-yyp
    ydif = [(yobs[nn]-ypred[nn]) for nn in range(0,len(yobs))]
    
    xx = [zz for zz in range(0,len(yobs))]
    men=0
    amen=0
    for val in ydif:
        men = men + val[0]
        amen = amen + abs(val[0])
    print(men,amen)
    men=men/len(ydif)
    amen=amen/len(ydif)
    print("R ",type(men),type(amen))
    #xlabs = yrmos[0:nrows:60]
    #fig = plt.figure()
    fig, ax1 = plt.subplots(2)
    ax1[0].set_xticks(xticks)
    ax1[0].set_xticklabels(xlabs)
    ax1[0].plot(xx,yobs,label="Obsv",marker="s")
    ax1[0].plot(xx,ypred,label="Pred",marker="X")
    ax1[0].plot(xx,meansPlot,label="Mean",marker="")
    ax1[0].legend(loc="upper left")
    ax1[0].set_xticklabels(xlabs,fontsize=8.)
    ax1[0].tick_params(axis="x",direction="in")

    ax1[0].set_title(f"Observed and Predicted for Neural Network for phase shift of {nphs}")
    plt.setp(ax1[0].get_xticklabels(), rotation=0,rotation_mode="anchor")

  
#    ax1[1].set_title(f"Observed - Predicted for Neural Netowrk for phase shift of {nphs}")
#    ax1[1].plot(xx,mdiff,label="(Obsv-Mean)/std",marker="x")
#    ax1[1].set_xticks(xticks)
#    ax1[1].set_xticklabels(xlabs,fontsize=8.)
#    ax1[1].tick_params(axis="x",direction="in")
#    ax1[1].legend(loc="upper left")
  
#    cell_text = []
#    cell_text.append([f"Avg Dif={men:.4f}",f"Abs Dif = {amen:.4f}",
#                     f"Layers = {nlayers}",f"nodes={nnodes}"])
#    tbl = plt.table(cellText=cell_text,
#                  rowLabels=[" "],
#                  colLabels=[" "," "," "," "],
#                  loc='bottom')
#    for key, cell in tbl.get_celld().items():
#        cell.set_linewidth(0)
#    plt.subplots_adjust(bottom=-0.50)
#    plt.tight_layout()
#    plt.show()

# %% [markdown]
# ## Train

# %%
def train(XX,yy,nsplit,toScale,phase,yrmos):
    ''' create a Train, Test and Experiment datasets out of the input data. If toScale=1, then
    the data will also be scaled.  If toScale=0, the data will not be scaled.  The Experiment 
    time series will be the last nsplit values in the XX and yy lists. The Experiment time series 
    will be used for creating prediction scores'''
    
    info = {}
    info["y_test"] = {}
    info["y_train"] = {}
    ninst = len(yy)  # length of input time series
    yy = yy[phase:]
    yrmosShift = yrmos[phase:]
    XX = XX[0:ninst-phase]
    ntlen=ninst
    ninst = len(yy)  # length of input time series
    print ("LENS ",len(yy),len(XX))
   
    y=yy[0:ninst-nsplit]  #  this will be used to create the Train and Test time sries for the dependant variables
    X=XX[0:ninst-nsplit]  #  this will be used to create the Train and Test time series for the independant variables
    if (nsplit > 0):
        X_exp = XX[ninst-nsplit:]  # create the X experimental dataset for predictions
        y_exp = yy[ninst-nsplit:]  # create the y experimental dataset for predictions
    else:
        X_exp = []
        y_exp = []
    yrmosShift = yrmosShift[0:ninst-nsplit]
    feature_info = ""
    print(ninst,nsplit,ninst-nsplit,len(y_exp))
  #  feature_info = mutual_info_regression(X, y)  #  this can be turned off if you want to look at feature importance
   
#  creat the test and 
#    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)
    nlen = int(len(y)*.8)  # use 80% of data for training
#  New method for train and test datea keeps time series togther instead of using random selected points
    X_train = X[:nlen] 
    X_test = X[nlen:] 
    y_train = y[:nlen] 
    y_test = y[nlen:] 
    
    info["y_train"]["start"] = phase
    info["y_train"]["end"] = phase+nlen-1
    info["y_test"]["start"] = phase+nlen
    info["y_test"]["end"] = phase+ninst-nsplit-1
    yrmosTrain = yrmosShift[:nlen]
    yrmosTest = yrmosShift[nlen:]
    # create the scaler objects 
    X_scaler = StandardScaler().fit(X_train)
    y_scaler = StandardScaler().fit(y_train)
    if (toScale == 0):  # do not scale data, so return the unsclaled Train,Test and Experiment data
        return (X_train,X_test,X_exp,y_train,y_test,y_exp,feature_info,X_scaler,y_scaler)

    
#  create the scaled Train,Test and Predictio time series for the dependent variable    
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    if (nsplit > 0):
       X_exp_scaled = X_scaler.transform(X_exp)
    else:
       X_exp_scaled = []

#  create the scaled Train,Test and Predictio time series for the independent variable  
    y_train_scaled = y_scaler.transform(y_train)
    y_test_scaled = y_scaler.transform(y_test)
 #   y_exp_scaled = y_scaler.transform(y_exp)

    return (info,yrmosTrain,yrmosTest,X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
            y_test_scaled,y_exp,feature_info,X_scaler,y_scaler,y_train,y_test,nlen,ntlen)

# %% [markdown]
# # Climate Data

# %%
#indices = []  #  contains climate indices
dtype = 0
temp = []  # temporary list/dict used throught the program 
features = pd.DataFrame()  # this is a Pandas Dataframe that will hold the Climate Indices

#  add year-month pairs to the features dataframe that will match the available data
for year in range(1950,2019):
    for month in range(1,13):
        yrmo = year*100 + month
        temp.append(yrmo)
        
features['yearmo'] = temp

#  the Climate Indices are stored in flat files, so read them all in and store them in features
with open("data/file_list","r") as F:
    for file in F:
        file = file.rstrip("\n")
        spl = file.split(".")
        name = spl[0]
        temp = []
        with open(f"data/{file}","r") as fin:
            line=fin.readline()
            spl = line.split()
            start = int(spl[0])
            end = int(spl[1])
            for nn in range(start,end):
               line = fin.readline()
               spl = line.split()
               year = int(spl[0])
               if (year >= 1950 and year <= 2018):
                  for val in spl[1:]:
                    if float(val) != -99.99:
                      temp.append(val)
            if len(temp) == 828:
                features[name] = temp
                features[name] = features[name].astype('float')
#    temp["yearmo"] = features["yearmo"][(features["yearmo"] >= start) & (features['yearmo'] <= end)].astype(float)
    features["month"] =  features["yearmo"].astype(str)
    
    for i in range(0, len(features)): 
        features.loc[i,"month"] = features.loc[i,"month"][4:]
    features["month"] = features["month"].astype(int)
    print (features.head())

def selectIndices(indicesString,features,start,end,dtype):
#  dtype  0 = return observations   1 = return anomalies 
    temp = pd.DataFrame()
    indices =indicesString.split(",")
    
    for val in indices:
      val = val.lower()
      print (val)
      temp[val] = features[val][(features["yearmo"] >= start) & (features['yearmo'] <= end)].astype(float)
    
    if (dtype == 1):
      temp["month"] = features["month"][(features["yearmo"] >= start) & (features['yearmo'] <= end)].astype(float)
#      meanIndices = pd.DataFrame({"month":[mm for mm in range(1,13)]})
      means = {}
      for col in indices:
        means[col] = {}
        for mon in range(1,13):
          df = temp[col][temp["month"] == mon]
          mean = df.mean()
          means[col][mon] = mean
    
      
      for col in indices:
        colindex = temp.columns.get_loc(col)
        temp.insert(colindex,f"{col} Anom",np.nan)
        for i,row in temp.iterrows():
            val = row[col]
            mon = row["month"]
            row[f"{col} Anom"] = val-means[col][mon]
      pprint.pprint(means)
      for col in indices:
          temp  = temp.drop(col,axis=1)
      temp  = temp.drop("month",axis=1)      
      print(temp.head())
 
    nl = len(indices)
    X = temp.values.reshape(-1,nl).astype(float) 
    return (X)
# Out:
#    yearmo  ammsst  ammwind    amo   epo  nina1  nina3  nina34  nina4   oni  \
# 0  195001    0.53     1.10  0.111  0.91  23.01  23.56   24.55  26.94 -1.53
# 1  195002   -1.07    -5.12 -0.033 -1.13  24.32  24.89   25.06  26.67 -1.34
# 2  195003   -1.26    -0.42 -0.105 -0.02  25.11  26.36   25.87  26.52 -1.16
# 3  195004    0.72     1.67 -0.130 -1.87  23.63  26.44   26.28  26.90 -1.18
# 4  195005    1.05     4.21 -0.058 -0.98  22.68  25.69   26.18  27.73 -1.07
#
#     pna    qbo   tna    tni   tsa  whwp  month
# 0 -3.65  -8.99 -0.14  0.624  0.08 -0.17      1
# 1 -1.69 -11.37 -0.36  0.445  0.15 -0.30      2
# 2 -0.06 -10.63 -0.37  0.382  0.12 -0.96      3
# 3 -0.23  -8.19 -0.11  0.311 -0.17 -1.93      4
# 4 -0.40  -6.09 -0.25  0.124 -0.34 -2.27      5

# %% [markdown]
# # City Data

# %%
#city="DENVER"
#variable="TMAX"
#mydoc = mycol.find({"city":city})
#indices = "nina1,nina4,oni,tni"
#  convert year-month string to integers
#features['yearmo'] = features['yearmo'].astype(int)
#  print (features.info())

def getData(city,variable,dtype):
    client = pymongo.MongoClient("mongodb+srv://jgirlsdad:444jayla@cluster0-dgjk9.mongodb.net/test?retryWrites=true&w=majority")
    mydb = client.climate
    mycol = mydb["monthly-new"]
    mydoc = mycol.find({"city":city})
    data_hold = {}
    years = {}
    data = pd.DataFrame()

    # iterate over returned data from MondoDB and extract requested variable
    for x in mydoc:  
        temp = []
        yrmos = []

        for key in x[variable]:
            year,mo = key.split("-")
            years[year]=1
            yrmo = key.replace("-","")
            yrmos.append(int(yrmo))
            temp.append(x[variable][key])
        data[variable] = temp
        start = min(yrmos)
        end = max(yrmos)

    yrs = [yr for yr in sorted (years.keys())]
    #print(yrs)
    #  reshaped data for input into neural netowrk
    y = data[variable].values.reshape(-1,1).astype(float)
    
    hold = data[variable].values.reshape(len(yrs),12)
    data_bymonth = pd.DataFrame(hold)
    data_checks = pd.DataFrame()
    data_checks["Obs"] = data[variable]
    data_checks["Date"] = yrmos
    data_checks.insert(0,"Var",variable)
    print(data_checks.head())
#    data_bymonth.rename(columns={0:"Jan",1:"Feb",2:"Mar",3:"Apr",4:"May",5:"Jun",6:"Jul",7:"Aug",8:"Sep",9:"Oct",10:"Nov",11:"Dec"},inplace=True)
    data_bymonth["Year"] = yrs
#    print(data_bymonth.head())
    Stats = {}
    Means = []
    Stds = []
    Mons = []
    for mon in data_bymonth.columns:
        Stats[mon]={}
        data_bymonth[mon]=data_bymonth[mon].astype(float)
        Stats[mon]['std'] = data_bymonth[mon].std()
        Stats[mon]['mean'] = data_bymonth[mon].mean()
        Stds.append(Stats[mon]['std'])
        Means.append(Stats[mon]['mean'])
        Mons.append(mon)
    
    data_bymonth  = data_bymonth.set_index("Year")
    if (dtype == 0):   #  Return actual Monthly means for the variable
        return y,yrs,yrmos,Stats,Means,Stds,data_checks
    y=[]
    zz = []
    for index,row in data_bymonth.iterrows():
        for mon in range(0,12):
            anom = data_bymonth.loc[index,mon] - Means[mon]
            yy=[]
            yy.append(anom)
            zz.append(anom)
            y.append(yy)
  #  data_bymonth['Year'] = yrs
    #print(data_bymonth.head())
    data_checks["Anom"] = zz
    traceMsg("done")
    return y,yrs,yrmos,Stats,Means,Stds,data_checks

#print(X)

#(y,yrs,yrmos,cityStats,cityMeans,cityStds,data_checks) = getData("DENVER","TMIN",1)

# %%
def plotMeanStdv(xx,means,stds,city):   
    
    fig, ax1 = plt.subplots()
    ax1.plot(xx,means,label="Mean",marker="s",color="blue")
    ax1.legend(loc="upper left")
    ax1.set_ylabel('Mean',color="blue")  # we already handled the x-label with ax1
    ax1.set_title(f"Long Term Monthly Mean and Standard Deviation for {city}")

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    ax2.plot(xx,stds,label="Std Dev",marker="X",color="red")
    ax2.set_ylabel('Standard Deviation',color="red")  # we already handled the x-label with ax1
    ax2.legend(loc="upper right")



plotMeanStdv(cityMons,cityMeans,cityStds,city)

# %% [markdown]
# # Talos

# %%
import talos
from keras.models import Sequential
from keras.layers import Dropout, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import sys
# %matplotlib inline
def train(XX,yy,nsplit,toScale,phase):
    ''' create a Train, Test and Experiment datasets out of the input data. If toScale=1, then
    the data will also be scaled.  If toScale=0, the data will not be scaled.  The Experiment 
    time series will be the last nsplit values in the XX and yy lists. The Experiment time series 
    will be used for creating prediction scores'''
  
    ninst = len(yy)  # length of input time series
    yy = yy[phase:]
    XX = XX[0:ninst-phase]
    print ("LENS ",len(yy),len(XX))
    y=yy[0:ninst-nsplit]  #  this will be used to create the Train and Test time sries for the dependant variables
    X=XX[0:ninst-nsplit]  #  this will be used to create the Train and Test time series for the independant variables
    X_exp = XX[ninst-nsplit:]  # create the X experimental dataset for predictions
    y_exp = yy[ninst-nsplit:]  # create the y experimental dataset for predictions
    feature_info = ""
  #  feature_info = mutual_info_regression(X, y)  #  this can be turned off if you want to look at feature importance
   
#  creat the test and 
    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)
   
    # create the scaler objects 
    X_scaler = StandardScaler().fit(X_train)
    y_scaler = StandardScaler().fit(y_train)
    
    if (toScale == 0):  # do not scale data, so return the unsclaled Train,Test and Experiment data
        return (X_train,X_test,X_exp,y_train,y_test,y_exp,feature_info,X_scaler,y_scaler)

    
#  create the scaled Train,Test and Predictio time series for the dependent variable    
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    X_exp_scaled = X_scaler.transform(X_exp)
   
#  create the scaled Train,Test and Predictio time series for the independent variable  
    y_train_scaled = y_scaler.transform(y_train)
    y_test_scaled = y_scaler.transform(y_test)
    y_exp_scaled = y_scaler.transform(y_exp)

    return (X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
            y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler)

def breast_cancer_model(x_train, y_train, x_val, y_val, params):

    model = Sequential()
#    model.add(Dense(params['first_neuron'], input_dim=x_train.shape[1],
#                    activation=params['activation'],
#                    kernel_initializer=params['kernel_initializer']))
    
    model.add(Dense(params['first_neuron'], input_dim=x_train.shape[1],
                    activation=params['activation'],
                    ))
    

#    model.add(Dropout(params['dropout']))

  #  model.add(Dense(1, activation=params['last_activation'],
  #                  kernel_initializer=params['kernel_initializer']))
    model.add(Dense(1,))  
    model.compile(loss=params['losses'],
                  optimizer=params['optimizer'],
                  metrics=['mse', talos.utils.metrics.f1score])
    
    history = model.fit(x_train, y_train, 
                        validation_data=[x_val, y_val],
        #                batch_size=params['batch_size'],
                        callbacks=[talos.utils.live()],
                        epochs=params['epochs'],
                        verbose=0)

    return history, model

yy = [nn for nn in y]
(X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
    y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler) = \
train(X,yy,24,1,4)


#modl =  breast_cancer_model(x_train_scale, y_train, x_val, y_val, params):
#p = {'first_neuron':[9,10,11],
#     'hidden_layers':[0, 1, 2,3,4],
#     'units': [4,8,12,14],
#     'batch_size': [len(y)],
#     'epochs': [30],
#     'dropout': [1],
#     'kernel_initializer': ['uniform','normal'],
#     'optimizer': [ 'Adam'],
#     'losses': ['MSE'],
#     'activation':['relu'],
#     'last_activation': ['sigmoid']}

p = {'first_neuron':[9,10,11],
     'hidden_layers':[0, 1, 2,3,4],
     'units': [4,8,12,14],
     
     'epochs': [30],
    
    
     'optimizer': [ 'Adam'],
     'losses': ['MSE'],
     'activation':['relu'],
     }


# and run the experiment
print("starting")

t = talos.Scan(x=X_train_scaled,
               y=y_train_scaled,
               x_val=X_test_scaled,
               y_val=y_test_scaled,
               model=breast_cancer_model,
               params=p,
               experiment_name='Climate Test 1',
               disable_progress_bar=False,
               print_params=True,
               round_limit=10)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:35<00:00, 21.44s/it]

# %% [markdown]
# ## Talos Best Model

# %%
best_model = t.best_model(metric='mse', asc=True)
Y_pred = best_model.predict(X_exp_scaled)

#print(Y_pred)
print(best_model)
r = talos.Reporting(t)
# Show the models
display(r.data)
#print(Y_Pred)
y_predict = y_scaler.inverse_transform(Y_pred)
y_exp = y_scaler.inverse_transform(y_exp_scaled)
#print(y_predict)
#print (y_exp_scaled)
# Out:
# here
# <keras.engine.sequential.Sequential object at 0x000001FBF336D6A0>
#    round_epochs  val_loss   val_mse  val_f1score      loss       mse  \
# 0            30  0.168105  0.168105     1.661626  0.172505  0.172505
# 1            30  0.177505  0.177505     1.717262  0.168881  0.168881
# 2            30  0.197077  0.197077     1.631925  0.192985  0.192985
# 3            30  0.160384  0.160384     1.609515  0.157411  0.157411
# 4            30  0.172999  0.172999     1.694738  0.173447  0.173447
# 5            30  0.182383  0.182383     1.740487  0.201732  0.201732
# 6            30  0.187239  0.187239     1.701020  0.184252  0.184252
# 7            30  0.172027  0.172027     1.679247  0.164278  0.164278
# 8            30  0.181382  0.181382     1.741548  0.178203  0.178203
# 9            30  0.168750  0.168750     1.662454  0.168072  0.168072
#
#     f1score activation  epochs  first_neuron  hidden_layers losses optimizer  \
# 0  1.719296       relu      30             9              0    MSE      Adam
# 1  1.753851       relu      30             9              3    MSE      Adam
# 2  1.718553       relu      30            11              1    MSE      Adam
# 3  1.729838       relu      30             9              1    MSE      Adam
# 4  1.725039       relu      30            11              2    MSE      Adam
# 5  1.769708       relu      30             9              2    MSE      Adam
# 6  1.678276       relu      30            10              1    MSE      Adam
# 7  1.775561       relu      30            10              0    MSE      Adam
# 8  1.704408       relu      30            10              4    MSE      Adam
# 9  1.738585       relu      30            10              2    MSE      Adam
#
#    units
# 0      8
# 1      8
# 2      8
# 3      4
# 4      8
# 5      8
# 6     14
# 7     12
# 8     12
# 9      4

# %% [markdown]
# ## Plot Talos

# %%
yobs = y_exp
ypred = y_predict
#print(yobs)
nlayers=0
nnodes=0
nsplit=24
#plotObPrNeural(4,yobs,ypred,yrmos,indices,nlayers,nnodes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cbf253eb18b8> in <module>
#      59
#      60
# ---> 61 yobs = y_exp
#      62 ypred = y_predict
#      63 #print(yobs)
#
# NameError: name 'y_exp' is not defined

# %% [markdown]
# # Orig Neural Net

# %%
def neuralNet(X,y,layers,nodes):
    ''' This runs the Regression Neural Network using the input # of layers and nodes '''
#  train the data... note the data is scaled as this is a Regression 
    X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled,y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler = train(X,y,24,1)

 
    nd = X.shape
    ndims = nd[1]

#  create Neural Network Modeladn the number of nodes for each layer
    model = Sequential()

#  add layers to the network 
    for nn in range(1,layers):
      print ("Adding Layer ",nn)
      model.add(Dense(units=nodes, activation='relu', input_dim=ndims))

#  add the ouput layers
    model.add(Dense(units=1))
    
#  compile the model
    model.compile(optimizer='adam',
                loss='mse',
                metrics=['mse'])
   
#  fit the model, use 100 epochs, but at some point, let users input the number of epochs
    history = model.fit(
        X_train_scaled,
        y_train_scaled,
        epochs=100,
        shuffle=True,
        verbose=0,
        validation_split = 0.2
    )
    hist = pd.DataFrame(history.history)

    model.summary()

# predict the dependent values for the for Experiment/Prediction time series
    y_predict = model.predict(X_exp_scaled)
    
#  score the Experiment data
    r2 = model.evaluate(X_exp_scaled,y_exp_scaled)
    
    mde=0
#  unscale the data 
    y_predict = y_scaler.inverse_transform(y_predict)
    y_exp_scaled = y_scaler.inverse_transform(y_exp_scaled)

#  create the error score so that we now exactly how well the predictions worked
    for nn in range(0,len(y_exp_scaled)):
        mde+= (y_exp_scaled[nn][0]-y_predict[nn][0])**2
        
   # mde=math.sqrt(mde/len(y_exp_scaled))
    mde=r2
#  convert the different Numpy arrays to Python lists so that jsonify can handle them
    bb = []
    hold = []
    for a in y_exp_scaled:
      bb.append(float(a[0]))

    cc = []
    for a in y_predict:
      cc.append(float(a[0]))
    
    temp = {}
    temp["r2"] = mde  #  my created MDE score 
    
    temp['y_obs'] = bb  # original data for precition comparison
    temp['y_pred'] = cc # the predicted values from the model
     

#  convert the Numpy arrays to Python lists
 #   temp['mse'] = hist['mean_squared_error'].values.tolist()
 #   temp['mse_val'] = hist['val_mean_squared_error'].values.tolist()

    hold.append(temp)

    return hold
layers=2
nodes=8

scores = neuralNet(X,yy,layers,nodes)
print(scores)
# Out:
# Adding Layer  1
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 8)                 40
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________
# 24/24 [==============================] - 0s 166us/step
# [{'r2': [0.5863639712333679, 0.5863639712333679], 'y_obs': [42.4, 55.5, 63.6, 63.5, 69.2, 86.8, 92.0, 87.0, 79.8, 65.5, 61.0, 49.0, 48.5, 42.5, 58.0, 63.1, 75.5, 90.5, 89.2, 86.1, 82.9, 62.4, 51.3, 46.5], 'y_pred': [64.0460205078125, 55.84109115600586, 54.15337371826172, 61.89072036743164, 63.780113220214844, 70.020263671875, 77.54351043701172, 81.27913665771484, 82.60334777832031, 80.54371643066406, 78.02266693115234, 72.71430206298828, 61.96009826660156, 58.16934585571289, 60.448455810546875, 65.18035125732422, 70.26187896728516, 75.76947784423828, 78.52812194824219, 82.5369644165039, 81.05353546142578, 78.62720489501953, 69.21546173095703, 61.048797607421875]}]

# %% [markdown]
# ## Plot Orig Neural Net

# %%
yobs = scores[0]['y_obs']
ypred = scores[0]['y_pred']
print(yobs)
nlayers = layers
nnodes = nodes
plotObPrNeural(4,yobs,ypred,yrmos,indices,nlayers,nnodes)
# Out:
# [42.4, 55.5, 63.6, 63.5, 69.2, 86.8, 92.0, 87.0, 79.8, 65.5, 61.0, 49.0, 48.5, 42.5, 58.0, 63.1, 75.5, 90.5, 89.2, 86.1, 82.9, 62.4, 51.3, 46.5]
# [201701, 201706, 201801, 201806, 201812]
# -73.43795700073242 252.40376358032228
# R  -3.059914875030518 10.516823482513429

# %%
import talos
from keras.models import Sequential
from keras.layers import Dropout, Dense
from keras.layers import LSTM
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import sys
# %matplotlib inline

yy = [nn for nn in print (yy)
(X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
    y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler) = \
train(X,yy,24,1,4)

# %% [markdown]
# # LSTM Neural Net

# %%
#cities = ["DENVER","NEW YORK CITY","LOS ANGELES","SAN FRANCISCO","NEW ORLEANS"]


def reshapeTS(ts,nperiod):
    tsnew = []
    nlen = len(ts)
    nfeats = ts.shape[1]
#    traceMsg("start reshape ",nlen,nfeats,ts.shape,ts[0:10])
    for ii in range(nperiod,nlen):
      tmp = []
      for jj in range(0,nfeats):
          hld = []
          for mm in range(ii-nperiod,ii+1):
              hld.append(ts[mm][jj])
          tmp.append(hld)
      tsnew.append(tmp)
    
    tsnew = np.array(tsnew)
#    print("shape ",nperiod,tsnew[0:3])
#    npr = nperiod
    return tsnew


def neuralLSTM(city,variable,indices,dtype,nphase,nperiod,ttype,nsplit):
#  dtype   -  1 = use actual obs   2 = use anaomalies
#  nphase  - amount of the phase shift
#  nperiod - how many time steps to go back in time for each point
#  ttype   - 1 = use Training data for stats   2 = use Test data for stats
    (y,yrs,yrmos,cityStats,cityMeans,cityStds,data_checks) = getData(city,variable,dtype)
    X = selectIndices(indices,features,195001,201812,dtype)
    traceMsg(X)
    print(city,variable)
    yy = [nn for nn in y]
    (info,yrmosTrain,yrmosTest,X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
    y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler,y_train,y_test,nlen,ntlen) = \
    train(X,yy,nsplit,1,nphase,yrmos)
    traceMsg("INFO  ",info)
    traceMsg("TTTRAIN ",ttype)
    y_train = y_train[nperiod:]
    y_test = y_test[nperiod:]
    info["y_train"]["start"]+=nperiod
    info["y_test"]["start"]+=nperiod
    #y_train_scaled = [nn for nn in y_train_scaled]
    y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0]))
    y_test_scaled = y_test_scaled.reshape((y_test_scaled.shape[0]))

    y_train_scaled = y_train_scaled[nperiod:]
    y_test_scaled = y_test_scaled[nperiod:]
    print(y_train_scaled.shape)
#    X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
#    X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))
#    X_exp_scaled = X_exp_scaled.reshape((X_exp_scaled.shape[0], 1, X_exp_scaled.shape[1]))


    X_train_scaled = reshapeTS(X_train_scaled,nperiod)
    X_test_scaled = reshapeTS(X_test_scaled,nperiod)
    if (nsplit > 0):
        X_exp_scaled = reshapeTS(X_exp_scaled,nperiod)
    #y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0], 1, y_train_scaled.shape[1]))
    #X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))

    model = Sequential()
#    model.add(LSTM(50, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
    model.add(LSTM(64, return_sequences=True,input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(64))
    model.add(Dense(1))
    model.add(Dense(1))
    model.add(Dense(1))
    
    model.add(Dense(1))
    model.add(Dense(1))
#    model.add(Dense(1))
##    model.add(Dense(1))
#    model.add(Dense(1))
#    model.add(Dense(1))
#    model.add(Dropout(0.2))
    model.compile(loss='mae', optimizer='adam')
    # fit network
    traceMsg("X_train_scaled ",X_train_scaled.shape)
    traceMsg("y_train_scaled ",y_train_scaled.shape)
    traceMsg("X_test_scaled ",X_test_scaled.shape)
    traceMsg("y_test_scaled ",y_test_scaled.shape)    
        
    history = model.fit(X_train_scaled, y_train_scaled, epochs=50, batch_size=24, validation_data=(X_test_scaled, y_test_scaled), verbose=0, shuffle=False)
    # plot history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
    if (nsplit > 0):
        y_predict = model.predict(X_exp_scaled)
        y_predict = y_scaler.inverse_transform(y_predict)
    y_train_predict = model.predict(X_train_scaled)
    y_train_predict = y_scaler.inverse_transform(y_train_predict)
   
    y_test_predict = model.predict(X_test_scaled)
    y_test_predict = y_scaler.inverse_transform(y_test_predict)
    
 
## Compute Accuracy Stats
 #   diffs = pd.DataFrame({"Dates":yrmosNew})
 #   diffs=data_checks.loc[nphase+nperiod:nlen+nphase-1]
#    diffs = diffs.set_index("Date")
#    print(diffs.head())
#    print(len(diffs))
    traceMsg("ttype ",ttype)
    if (ttype == 1):
        y_ts = [mm[0] for mm in y_train]
        y_ts_predict = [mm[0] for mm in y_train_predict]
        yrmosNew = yrmosTrain[nperiod:]
        diffs=data_checks.loc[nphase+nperiod:nlen+nphase-1]
    elif (ttype == 2):
        y_ts = [mm[0] for mm in y_test]
        y_ts_predict = [mm[0] for mm in y_test_predict] 
        yrmosNew = yrmosTest[nperiod:]
        ntststrt = info["y_test"]["start"]
        ntstend = info["y_test"]["end"]
        diffs=data_checks.loc[ntststrt:ntstend]
    
#    traceMsg("y_ts len ",len(y_ts))
#    traceMsg("yrmos len ",len(yrmosNew))
    diffs = diffs.set_index("Date")
    
#    traceMsg("len diffs ",len(diffs))
#    traceMsg("diff \n",diffs)
#    yrmosNew = yrmosNew[nperiod:]
#    print("yrmosNew ",len(yrmosNew),yrmosNew)
    diffs["Months"] = [ int(str(m)[4:6]) for m in yrmosNew]
    y_train = [ m[0] for m in y_train]
    print("L",len(y_ts),len(y_ts_predict))
    diffs["Train Obs"] = y_ts
    diffs["Train Pred"] = y_ts_predict
    diffs["Obs-Pred"] = diffs["Train Obs"] - diffs["Train Pred"]
    diffs["abs(Obs-Pred)"] = abs(diffs["Train Obs"] - diffs["Train Pred"])
    hld = []
    hldp = []
    if (dtype == 1):  # processing anomalies, so add them back to mean
        for index,row in diffs.iterrows():
            mon = diffs.loc[index,"Months"]
            anom = diffs.loc[index,"Train Obs"] + cityMeans[mon]
            hld.append(anom)
            pred = diffs.loc[index,"Train Pred"] + cityMeans[mon]
            hldp.append(pred)
    
        #    diffs["Obs"] = hld
        #    diffs["Pred"] = hldp
#    traceMsg("diff h",diffs.head())
    df = pd.DataFrame()
#    traceMsg(diffs.groupby(["Months"]).mean())
  #  df["Month"] = [m for m in range(1,13)]
    df["Mean Obs"] = diffs.groupby(["Months"]).mean()["Train Obs"]
    df["Mean Pred"] = diffs.groupby(["Months"]).mean()["Train Pred"]
    df["Mean O-P"] = diffs.groupby(["Months"]).mean()["Obs-Pred"]
    df["Mean abs(O-P)"] = diffs.groupby(["Months"]).mean()["abs(Obs-Pred)"]

    df["StdD Obs"] = diffs.groupby(["Months"]).std()["Train Obs"]
    df["StdD Pred"] = diffs.groupby(["Months"]).std()["Train Pred"]
    df["StdD O-P"] = diffs.groupby(["Months"]).std()["Obs-Pred"]
    df["StdD abs(O-P)"] = diffs.groupby(["Months"]).std()["abs(Obs-Pred)"]
    df["abs(O-P)/Std"] = df["Mean abs(O-P)"]/df["StdD Obs"]
    df.insert(0,"City",city)
    df.insert(1,"Var",variable)
    df.insert(2,"Phase",nphase)
    df.insert(3,"Period",nperiod)
    df.insert(4,"Dtype",dtype)
    df.insert(5,"Ttype",ttype)
    df.insert(5,"Start",yrmosNew[0])
    df.insert(5,"End",yrmosNew[-1])
    df["Month"] = [m for m in range(1,13)]
#    print (diffs.head())
    wi = df[(df["Month"] == 1) |  (df["Month"] == 12) | (df["Month"] == 2)]
    sp = df[(df["Month"] == 3) |  (df["Month"] == 4) | (df["Month"] == 5)]
    su = df[(df["Month"] == 6) |  (df["Month"] == 7) | (df["Month"] == 8)]  
    fa = df[(df["Month"] == 9) |  (df["Month"] == 10) | (df["Month"] == 11)]
    summary_df = pd.DataFrame()
    summary_df["City"] = [city]
    summary_df["Var"] = [variable]
    summary_df["Period"] = nperiod
    summary_df["Phase"] = nphase
    summary_df["D-Type"] = dtype
    summary_df["T-Type"] = ttype
    summary_df["Start"] = [yrmosNew[0]]
    summary_df["End"] = [yrmosNew[-1]]
    summary_df["Winter"] = [wi["abs(O-P)/Std"].mean()]
    summary_df["Spring"] = [sp["abs(O-P)/Std"].mean()]
    summary_df["Summer"] = [su["abs(O-P)/Std"].mean()]
    summary_df["Fall"] = [fa["abs(O-P)/Std"].mean()]
#    print(wi)
    return df,summary_df,y_train,y_train_predict,yrmosNew,cityStats
#cities = ["DENVER","NEW YORK CITY","LOS ANGELES","SAN FRANCISCO","NEW ORLEANS"]

variables = ["TMIN"]
#cities = ["NEW YORK CITY"]
cities = ["DENVER"]
indices = "nina1,nina4,oni,tni"
dtype = 0  #  0 = Actual monthly observations    1 = Monthly anomalies
ttype = 2  #  1 = use Training data for stats    2 = using Testing data for stats
nn=0
nphase=0
nlayers=0
nnodes=0
#nsplit=24
nsplit=0
nperiodStart = 34
nperiodEnd = 36
for city in cities:
    for variable  in variables:
        for nperiod in range(nperiodStart,nperiodEnd+1):
            print (f"\n\n\n ----------------------{variable} PERIOD {nperiod}  ----------------------")
            starttime = timeit.default_timer()
            df1,sumry1,y_obs,y_pred,yrmosTrain,cityStats = neuralLSTM(city,variable,indices,dtype,nphase,nperiod,ttype,nsplit)
            print("The time difference is :", timeit.default_timer() - starttime)
            timer = timeit.default_timer() - starttime
            print("Dates ",yrmosTrain[-60:])
            df_tim = pd.DataFrame({"City":[city],"Var":[variable],"Period":[nperiod],"Phase":[nphase], \
                                           "Dtype":[dtype],"Ttype":[ttype],"Timer":[timer]})
            plotObPrNeuralNew(nphase,y_obs[-60:],y_pred[-60:],yrmosTrain[-60:],indices,nlayers,nnodes,cityStats)  
            nn+=1
            print("TIMER ",df_tim)
            if (nn > 1):    
                df = df.append(df1,ignore_index=True)
                sumry = sumry.append(sumry1,ignore_index=True)
                df_timer = df_timer.append(df_tim,ignore_index=True)
            else:
                df=df1
                sumry=sumry1
                df_timer = df_tim
 #   print(df)
    df.to_html(f"Output/df-{city}-{nphase}-{nperiodStart}-{nperiodEnd}-{dtype}-{ttype}.html")
    df.to_csv(f"Output/df2-{city}-{nphase}-{nperiodStart}-{nperiodEnd}-{dtype}-{ttype}.csv")
    print(sumry)
    sumry.to_html(f"Output/summry-{city}-{nphase}-{nperiodStart}-{nperiodEnd}-{dtype}-{ttype}.html")
    sumry.to_csv(f"Output/summry2-{city}-{nphase}-{nperiodStart}-{nperiodEnd}-{dtype}-{ttype}.csv")
    print(df_timer)
    df_timer.to_csv(f"Output/timer-{city}-{nphase}-{nperiodStart}-{nperiodEnd}-{dtype}-{ttype}.csv")
# Out:
#  ----------------------TMIN PERIOD 34  ----------------------
#     Var   Obs    Date
# 0  TMIN  13.7  195001
# 1  TMIN  24.6  195002
# 2  TMIN  23.8  195003
# 3  TMIN  33.3  195004
# 4  TMIN  40.3  195005
# nina1
# nina4
# oni
# tni
# (array([[23.01 , 26.94 , -1.53 ,  0.624],
#        [24.32 , 26.67 , -1.34 ,  0.445],
#        [25.11 , 26.52 , -1.16 ,  0.382],
#        ...,
#        [21.18 , 29.71 ,  0.7  , -1.89 ],
#        [22.46 , 29.61 ,  0.85 , -1.734],
#        [23.86 , 29.45 ,  0.82 , -1.7  ]]),)  from  neuralLSTM <= <module>
# DENVER TMIN
# LENS  828 828
# 828 0 828 0
# ('INFO  ', {'y_test': {'start': 662, 'end': 827}, 'y_train': {'start': 0, 'end': 661}})  from  neuralLSTM <= <module>
# ('TTTRAIN ', 2)  from  neuralLSTM <= <module>
# (628,)
# ('X_train_scaled ', (628, 4, 35))  from  neuralLSTM <= <module>
# ('y_train_scaled ', (628,))  from  neuralLSTM <= <module>
# ('X_test_scaled ', (132, 4, 35))  from  neuralLSTM <= <module>
# ('y_test_scaled ', (132,))  from  neuralLSTM <= <module>
# WARNING:tensorflow:From C:\Users\Science Joe\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e63cbe54a190> in <module>
#     210             print (f"\n\n\n ----------------------{variable} PERIOD {nperiod}  ----------------------")
#     211             starttime = timeit.default_timer()
# --> 212             df1,sumry1,y_obs,y_pred,yrmosTrain,cityStats = neuralLSTM(city,variable,indices,dtype,nphase,nperiod,ttype,nsplit)
#     213             print("The time difference is :", timeit.default_timer() - starttime)
#     214             timer = timeit.default_timer() - starttime
#
# <ipython-input-7-e63cbe54a190> in neuralLSTM(city, variable, indices, dtype, nphase, nperiod, ttype, nsplit)
#      83     traceMsg("y_test_scaled ",y_test_scaled.shape)
#      84
# ---> 85     history = model.fit(X_train_scaled, y_train_scaled, epochs=50, batch_size=24, validation_data=(X_test_scaled, y_test_scaled), verbose=0, shuffle=False)
#      86     # plot history
#      87     plt.plot(history.history['loss'], label='train')
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plotObPrNeural(4,y_exp_scaled,y_predict,yrmos,indices,nlayers,nnodes,cityStats)

# %% [markdown]
# ## Plot LSTM

# %%
#X_exp_scaled = X_exp_scaled.reshape((X_exp_scaled.shape[0], 1, X_exp_scaled.shape[1]))
#y_exp_scaled = y_scaler.inverse_transform(y_exp_scaled)

print(len(y_exp_scaled))
y_predict = model.predict(X_exp_scaled)
y_predict = y_scaler.inverse_transform(y_predict)
diffs = pd.DataFrame({"Dates":yrmosNew})
diffs["Months"] = [ int(str(m)[4:6]) for m in yrmosNew]

y_train_predict = model.predict(X_train_scaled)
y_train_predict = y_scaler.inverse_transform(y_train_predict)
print("L",len(y_train),len(y_train_predict))
diffs["Train Obs"] = [ m[0] for m in y_train]
diffs["Train Pred"] = y_train_predict
diffs["Obs-Pred"] = diffs["Train Obs"] - diffs["Train Pred"]
diffs["abs(Obs-Pred)"] = abs(diffs["Train Obs"] - diffs["Train Pred"])
df = pd.DataFrame()
df["Mean Obs"] = diffs.groupby(["Months"]).mean()["Train Obs"]
df["Mean Pred"] = diffs.groupby(["Months"]).mean()["Train Pred"]
df["Mean O-P"] = diffs.groupby(["Months"]).mean()["Obs-Pred"]
df["Mean abs(O-P)"] = diffs.groupby(["Months"]).mean()["abs(Obs-Pred)"]

df["StdD Obs"] = diffs.groupby(["Months"]).std()["Train Obs"]
df["StdD Pred"] = diffs.groupby(["Months"]).std()["Train Pred"]
df["StdD O-P"] = diffs.groupby(["Months"]).std()["Obs-Pred"]
df["StdD abs(O-P)"] = diffs.groupby(["Months"]).std()["abs(Obs-Pred)"]
df.insert(0,"City",city)
df.insert(1,"Var",variable)
print(df)

        
nlayers = 0
nnodes=0
nsplit=24
plotObPrNeural(4,y_exp_scaled,y_predict,yrmos,indices,nlayers,nnodes,cityStats)
# Out:
# 24
# L 640 640
#           City   Var   Mean Obs  Mean Pred  Mean O-P  Mean abs(O-P)  StdD Obs  \
# Months
# 1       DENVER  TMIN  17.167925  18.481586 -1.313661       3.924693  4.606132
# 2       DENVER  TMIN  20.547170  20.274801  0.272369       3.804965  3.941573
# 3       DENVER  TMIN  25.969811  25.337076  0.632735       3.120208  3.274763
# 4       DENVER  TMIN  34.437736  34.099686  0.338050       2.775071  3.048217
# 5       DENVER  TMIN  44.064815  46.129826 -2.065011       3.759633  2.377660
# 6       DENVER  TMIN  52.916667  54.974358 -2.057690       3.178233  2.682701
# 7       DENVER  TMIN  59.020370  57.368889  1.651482       2.680966  2.073952
# 8       DENVER  TMIN  57.442593  52.428787  5.013804       5.315115  1.901400
# 9       DENVER  TMIN  48.169811  43.748966  4.420845       5.210173  2.694623
# 10      DENVER  TMIN  36.788679  34.521080  2.267597       4.705538  2.622584
# 11      DENVER  TMIN  25.269811  26.821608 -1.551796       4.239782  2.911686
# 12      DENVER  TMIN  18.500000  20.612345 -2.112345       4.408448  4.031081
#
#         StdD Pred  StdD O-P  StdD abs(O-P)
# Months
# 1        2.815644  5.108769       3.486973
# 2        3.044621  4.912951       3.075145
# 3        3.060700  3.782869       2.189800
# 4        2.871638  3.538021       2.187455
# 5        3.431387  4.204729       2.760968
# 6        3.258953  3.424094       2.397216
# 7        2.837658  3.207435       2.396518
# 8        3.595922  4.014329       3.597764
# 9        4.163610  4.666385       3.745253
# 10       4.156756  5.335833       3.338277
# 11       4.148722  5.267294       3.446350
# 12       3.198347  5.456373       3.809419
# -33.33022232055664 82.10920715332031
# R  <class 'numpy.float64'> <class 'numpy.float64'>

# %% [markdown]
# # LSTM and Talos

# %%
def climate_model(x_train, y_train, x_val, y_val, params):

    model = Sequential()
#    model.add(Dense(params['first_neuron'], input_dim=x_train.shape[1],
#                    activation=params['activation'],
#                    kernel_initializer=params['kernel_initializer']))
    model.add(LSTM(50, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))

#    model.add(Dense(params['first_neuron'], input_dim=x_train.shape[1],
#                    activation=params['activation'],
#                    ))
    

#    model.add(Dropout(params['dropout']))

  #  model.add(Dense(1, activation=params['last_activation'],
  #                  kernel_initializer=params['kernel_initializer']))
    model.add(Dense(1,))  
    model.compile(loss=params['losses'],
                  optimizer=params['optimizer'],
                  metrics=['mse', talos.utils.metrics.f1score])
    
    history = model.fit(x_train, y_train, 
                        validation_data=[x_val, y_val],
        #                batch_size=params['batch_size'],
                        callbacks=[talos.utils.live()],
                        epochs=params['epochs'],
                        verbose=0)

    return history, model


(X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
    y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler) = \
train(X,yy,24,1,4)
print (X_exp_scaled)
#y_train_scaled = [nn for nn in y_train_scaled]
y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0]))
y_test_scaled = y_test_scaled.reshape((y_test_scaled.shape[0]))

print (type(y_train_scaled))
print(y_train_scaled.shape)
X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))
X_exp_scaled = X_exp_scaled.reshape((X_exp_scaled.shape[0], 1, X_exp_scaled.shape[1]))






#modl =  breast_cancer_model(x_train_scale, y_train, x_val, y_val, params):
#p = {'first_neuron':[9,10,11],
#     'hidden_layers':[0, 1, 2,3,4],
#     'units': [4,8,12,14],
#     'batch_size': [len(y)],
#     'epochs': [30],
#     'dropout': [1],
#     'kernel_initializer': ['uniform','normal'],
#     'optimizer': [ 'Adam'],
#     'losses': ['MSE'],
#     'activation':['relu'],
#     'last_activation': ['sigmoid']}

p = {'first_neuron':[9,10,11],
     'hidden_layers':[0, 1, 2,3,4],
     'units': [4,8,12,14],
     
     'epochs': [30],
    
    
     'optimizer': [ 'Adam'],
     'losses': ['MAE'],
     'activation':['relu'],
     }


# and run the experiment
print("starting")
print ("shape",X_train_scaled.shape)
t = talos.Scan(x=X_train_scaled,
               y=y_train_scaled,
               x_val=X_test_scaled,
               y_val=y_test_scaled,
               model=climate_model,
               params=p,
               experiment_name='Climate Test 1',
               disable_progress_bar=False,
               print_params=True,
               round_limit=10)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:00<00:00, 18.35s/it]

# %%
## LSTM and Taos Best Model

# %%
best_model = t.best_model(metric='mse', asc=True)
Y_pred = best_model.predict(X_exp_scaled)

Y_train_pred = best_model.predict(X_train_scaled)



#print(Y_pred)
print(best_model)
r = talos.Reporting(t)
# Show the models
display(r.data)
#print(Y_Pred)
y_predict = y_scaler.inverse_transform(Y_pred)
y_train_predict = y_scaler.inverse_transform(Y_train_pred)
#y_exp_scaled = y_scaler.inverse_transform(y_exp_scaled)
y_train_scaled = y_scaler.inverse_transform(y_train_scaled)
print(y_train_scaled)
nlayers = 0
nnodes=0
nsplit=24
plotObPrNeural(4,y_exp_scaled,y_predict,yrmos,indices,nlayers,nnodes,cityStats)
# Out:
# here
# <keras.engine.sequential.Sequential object at 0x0000020FCAA9CA58>
#    round_epochs  val_loss   val_mse  val_f1score      loss       mse  \
# 0            30  0.320203  0.154384     1.635223  0.308442  0.154605
# 1            30  0.319638  0.154358     1.616175  0.308529  0.155283
# 2            30  0.323404  0.158270     1.597714  0.309135  0.155719
# 3            30  0.326947  0.162236     1.603412  0.308251  0.154608
# 4            30  0.325359  0.160893     1.616175  0.309107  0.155394
# 5            30  0.322038  0.156579     1.657875  0.309164  0.155965
# 6            30  0.324278  0.159354     1.613098  0.308817  0.156114
# 7            30  0.324853  0.160473     1.591104  0.308436  0.155082
# 8            30  0.323672  0.158733     1.600791  0.308696  0.155572
# 9            30  0.323910  0.158610     1.632146  0.307972  0.154600
#
#     f1score activation  epochs  first_neuron  hidden_layers losses optimizer  \
# 0  1.724847       relu      30            11              1    MAE      Adam
# 1  1.684246       relu      30             9              4    MAE      Adam
# 2  1.684163       relu      30            11              4    MAE      Adam
# 3  1.704602       relu      30            10              2    MAE      Adam
# 4  1.693972       relu      30            11              3    MAE      Adam
# 5  1.712866       relu      30            10              3    MAE      Adam
# 6  1.726699       relu      30            11              4    MAE      Adam
# 7  1.711612       relu      30            11              4    MAE      Adam
# 8  1.675241       relu      30             9              0    MAE      Adam
# 9  1.710803       relu      30             9              0    MAE      Adam
#
#    units
# 0     12
# 1     12
# 2      4
# 3      8
# 4      8
# 5      8
# 6     12
# 7      8
# 8     12
# 9     14
# [65.6 81.1 81.8 83.  73.  76.7 53.2 50.5 39.1 47.2 49.5 55.8 70.1 73.5
#  87.9 83.9 76.5 61.2 51.7 41.1 48.4 48.4 46.1 61.3 69.1 87.3 87.6 86.2
#  80.7 69.3 44.9 44.5 52.9 45.8 57.7 54.8 65.8 84.2 87.1 84.6 81.5 68.
#  56.1 44.2 50.2 59.6 48.8 68.7 70.1 85.2 90.7 86.9 79.6 67.3 58.4 49.
#  38.8 40.1 50.4 64.9 72.5 77.2 90.4 86.1 77.9 69.5 49.  48.6 46.9 40.5
#  53.6 58.5 74.1 88.6 85.6 82.9 81.3 71.5 49.6 48.  38.2 54.6 51.4 52.6
#  64.6 79.3 86.5 85.8 75.9 62.1 47.6 54.  46.5 50.1 42.5 55.8 74.3 81.8
#  83.3 87.2 78.7 67.6 55.1 48.1 42.8 41.2 49.7 58.7 67.9 85.2 87.2 86.2
#  74.7 61.1 53.1 49.6 39.8 35.8 50.3 64.  70.3 82.4 86.9 89.7 80.8 66.1
#  54.3 38.9 44.  48.3 50.6 60.2 67.5 81.  87.6 86.6 69.3 65.2 47.4 40.6
#  33.4 41.4 46.9 64.4 75.3 80.4 89.2 89.9 79.2 70.6 55.5 49.  33.1 51.5
#  50.8 65.7 76.7 82.7 91.2 81.2 81.7 73.8 58.  43.9 45.5 39.6 45.1 59.8
#  74.4 79.9 92.4 86.1 78.9 70.2 52.3 46.1 48.8 40.7 40.4 65.3 70.6 76.3
#  86.8 84.4 68.1 71.9 59.2 49.4 44.  42.2 59.  59.7 74.9 79.7 92.  84.9
#  79.3 68.4 56.9 45.7 48.9 50.3 58.5 63.9 66.  72.8 82.3 82.9 77.5 68.6
#  56.4 40.5 44.1 47.2 55.8 57.8 68.6 84.6 86.4 82.1 76.6 68.4 48.5 44.1
#  49.8 49.7 44.9 66.6 71.9 73.7 88.8 88.8 79.  49.4 53.4 46.4 45.2 55.5
#  46.2 58.1 75.1 80.2 86.9 89.4 75.3 60.5 53.1 49.7 45.7 43.4 54.  62.2
#  68.3 86.4 86.2 88.6 72.5 64.7 54.2 46.4 45.9 51.9 61.2 62.9 71.2 82.8
#  85.7 85.3 76.  65.8 44.5 37.8 39.8 47.5 50.4 55.  68.3 83.6 85.7 88.8
#  74.3 70.4 53.4 45.  37.5 49.1 58.5 62.4 79.1 83.9 90.4 85.5 74.6 67.2
#  51.1 43.8 46.4 45.2 50.4 58.2 68.  79.5 87.2 86.2 75.3 70.5 50.8 50.5
#  46.3 54.1 51.7 62.9 70.3 82.  89.1 84.6 74.3 63.2 53.  50.9 43.9 51.8
#  53.9 63.3 74.9 86.3 87.8 83.  82.3 69.4 53.7 49.1 37.5 42.2 57.  63.6
#  67.1 80.6 90.4 85.5 81.2 68.1 49.8 36.9 30.6 47.3 52.  62.1 66.5 80.
#  89.5 82.5 80.7 67.7 44.5 47.6 37.5 46.1 49.9 59.4 68.4 87.  89.8 87.1
#  80.7 67.  55.3 55.  52.  51.8 52.5 70.2 67.4 84.2 90.  84.8 82.1 65.2
#  59.6 48.7 43.  46.2 54.9 61.6 66.8 75.5 86.4 86.4 73.9 62.9 48.6 43.1
#  42.1 47.4 45.5 51.7 62.5 75.  87.3 87.7 81.  67.9 49.4 28.2 39.  45.4
#  48.5 53.5 73.9 80.3 89.  84.5 74.1 55.1 54.3 45.7 37.5 40.4 54.6 63.8
#  73.  82.  86.3 87.7 71.5 65.1 40.4 41.6 54.7 48.7 61.  62.2 69.9 84.
#  88.  86.7 74.6 62.2 51.4 43.4 44.9 47.2 50.9 66.9 71.8 83.3 90.2 84.4
#  76.8 66.9 52.2 39.9 38.1 47.  51.  65.  72.8 86.  89.  87.7 77.7 69.9
#  54.  45.6 47.8 32.7 58.5 64.6 72.9 78.4 91.5 86.  76.5 65.8 57.7 40.9
#  48.6 45.2 51.3 61.1 70.7 89.  84.1 85.9 81.  67.4 57.8 39.5 41.4 54.
#  56.1 59.8 73.6 84.1 87.5 85.  77.  66.3 46.7 45.6 45.  52.5 55.3 69.3
#  73.8 79.4 84.1 82.3 81.4 69.8 45.8 38.8 39.4 40.6 55.3 61.6 72.6 81.2
#  89.  83.4 74.9 62.5 47.9 47.2 48.1 47.9 59.  61.8 77.4 89.7 89.5 89.8
#  82.8 64.9 50.5 49.7 47.2 52.4 53.1 54.4 59.7 75.4 86.3 90.7 74.9 65.
#  58.2 47.1 42.3 50.4 50.9 64.6 73.7 84.1 87.8 86.9 75.1 65.7 52.1 48.6
#  40.9 42.5 59.7 54.2 71.9 82.6 88.6 82.2 77.9 65.2 48.  41.  47.1 46.6
#  51.9 58.4 75.5 78.6 86.8 85.  82.8 63.7 56.  43.8 48.2 55.8 60.  55.8
#  68.4 79.3 88.7 83.6 73.3 68.3 64.3 48.1 48.4 53.2 54.2 66.  74.7 83.4
#  92.  89.3 78.5 65.2 42.1 43.1 44.3 40.4 52.  62.5 70.  84.  91.  86.9
#  81.8 67.6 57.9 47.7 45.5 48.7 49.3 67.6 71.2 88.2 92.8 87.9 78.4 59.5
#  50.6 48.6 53.3 42.4 52.9 65.7 70.4 76.2 94.  90.4]
# -22.061763000488284 96.04974212646486
# R  <class 'numpy.float64'> <class 'numpy.float64'>

# %% [markdown]
# # Testing

# %%
def reshapeTS(ts,nperiod):
    tsnew = []
    nlen = len(ts)
    nfeats = ts.shape[1]
#    traceMsg("start reshape ",nlen,nfeats,ts.shape,ts[0:10])
    for ii in range(nperiod,nlen):
      tmp = []
      for jj in range(0,nfeats):
          hld = []
          for mm in range(ii-nperiod,ii+1):
              hld.append(ts[mm][jj])
          tmp.append(hld)
      tsnew.append(tmp)
    
    tsnew = np.array(tsnew)
#    print("shape ",nperiod,tsnew[0:3])
#    npr = nperiod
    return tsnew


def neuralLSTMT(city,variable,indices,dtype,nphase,nperiod,ttype,nsplit):
#  dtype   -  1 = use actual obs   2 = use anaomalies
#  nphase  - amount of the phase shift
#  nperiod - how many time steps to go back in time for each point
#  ttype   - 1 = use Training data for stats   2 = use Test data for stats
    (y,yrs,yrmos,cityStats,cityMeans,cityStds,data_checks) = getData(city,variable,dtype)
    X = selectIndices(indices,features,195001,201812,dtype)
    traceMsg(X)
    print(city,variable)
    yy = [nn for nn in y]
    (info,yrmosTrain,yrmosTest,X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
    y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler,y_train,y_test,nlen,ntlen) = \
    train(X,yy,nsplit,1,nphase,yrmos)
    traceMsg("INFO  ",info)
    traceMsg("TTTRAIN ",ttype)
    y_train = y_train[nperiod:]
    y_test = y_test[nperiod:]
    info["y_train"]["start"]+=nperiod
    info["y_test"]["start"]+=nperiod
    #y_train_scaled = [nn for nn in y_train_scaled]
    y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0]))
    y_test_scaled = y_test_scaled.reshape((y_test_scaled.shape[0]))

    y_train_scaled = y_train_scaled[nperiod:]
    y_test_scaled = y_test_scaled[nperiod:]

    X_train_scaled = reshapeTS(X_train_scaled,nperiod)
    X_test_scaled = reshapeTS(X_test_scaled,nperiod)
    if (nsplit > 0):
        X_exp_scaled = reshapeTS(X_exp_scaled,nperiod)
    #y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0], 1, y_train_scaled.shape[1]))
    #X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))

    model = Sequential()
#    model.add(LSTM(50, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
    model.add(LSTM(64, return_sequences=True,input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(64))
    model.add(Dense(1))
    model.add(Dense(1))
    model.add(Dense(1))
    
    model.add(Dense(1))
    model.add(Dense(1))

    model.compile(loss='mae', optimizer='adam')
    
    traceMsg("X_train_scaled ",X_train_scaled.shape)
    traceMsg("y_train_scaled ",y_train_scaled.shape)
    traceMsg("X_test_scaled ",X_test_scaled.shape)
    traceMsg("y_test_scaled ",y_test_scaled.shape)    
        
    history = model.fit(X_train_scaled, y_train_scaled, epochs=50, batch_size=24, validation_data=(X_test_scaled, y_test_scaled), verbose=0, shuffle=False)
    # plot history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
    if (nsplit > 0):
        y_predict = model.predict(X_exp_scaled)
        y_predict = y_scaler.inverse_transform(y_predict)
    y_train_predict = model.predict(X_train_scaled)
    y_train_predict = y_scaler.inverse_transform(y_train_predict)
    y_train = [mm[0] for mm in y_train]
    y_test = [mm[0] for mm in y_test]
    y_test_predict = model.predict(X_test_scaled)
    y_test_predict = y_scaler.inverse_transform(y_test_predict)
    
    traceMsg("ttype ",ttype)
    df_test,summry_test = Stats(2,y_test,y_test_predict,yrmosTest[nperiod:],nphase,nperiod,nlen,info,data_checks) 
    df_train,summry_train = Stats(1,y_train,y_train_predict,yrmosTrain[nperiod:],nphase,nperiod,nlen,info,data_checks) 
#    print(wi)
    return df_test,summry_test,df_train,summry_train,y_train,y_train_predict,cityStats

def Stats(ttp,R2,y_ts,y_ts_predict,yrmosNew,nphase,nperiod,nlen,info,data_checks):
    if (ttp == 1):
##        y_ts = [mm[0] for mm in y_train]
#        y_ts_predict = [mm[0] for mm in y_train_predict]
#        yrmosNew = yrmosTrain[nperiod:]
        diffs=data_checks.loc[nphase+nperiod:nlen+nphase-1]
    elif (ttp == 2):
#        y_ts = [mm[0] for mm in y_test]
#        y_ts_predict = [mm[0] for mm in y_test_predict] 
#        yrmosNew = yrmosTest[nperiod:]
        ntststrt = info["y_test"]["start"]
        ntstend = info["y_test"]["end"]
        diffs=data_checks.loc[ntststrt:ntstend]
    
#    traceMsg("y_ts len ",len(y_ts))
#    traceMsg("yrmos len ",len(yrmosNew))
    diffs = diffs.set_index("Date")
    
    diffs["Months"] = [ int(str(m)[4:6]) for m in yrmosNew]
        
    diffs["Train Obs"] = y_ts
    diffs["Train Pred"] = y_ts_predict

    diffs["Obs-Pred"] = diffs["Train Obs"] - diffs["Train Pred"]
    diffs["abs(Obs-Pred)"] = abs(diffs["Train Obs"] - diffs["Train Pred"])
    hld = []
    hldp = []

    df = pd.DataFrame()
    
    df["Mean Obs"] = diffs.groupby(["Months"]).mean()["Train Obs"]
    df["Mean Pred"] = diffs.groupby(["Months"]).mean()["Train Pred"]
    df["Mean O-P"] = diffs.groupby(["Months"]).mean()["Obs-Pred"]
    df["Mean abs(O-P)"] = diffs.groupby(["Months"]).mean()["abs(Obs-Pred)"]

    df["StdD Obs"] = diffs.groupby(["Months"]).std()["Train Obs"]
    df["StdD Pred"] = diffs.groupby(["Months"]).std()["Train Pred"]
    df["StdD O-P"] = diffs.groupby(["Months"]).std()["Obs-Pred"]
    df["StdD abs(O-P)"] = diffs.groupby(["Months"]).std()["abs(Obs-Pred)"]
    df["abs(O-P)/Std"] = df["Mean abs(O-P)"]/df["StdD Obs"]
    df.insert(0,"City",city)
    df.insert(1,"Var",variable)
    df.insert(2,"Phase",nphase)
    df.insert(3,"Period",nperiod)
    df.insert(4,"Dtype",dtype)
    df.insert(5,"Ttype",ttp)
    df.insert(5,"Start",yrmosNew[0])
    df.insert(5,"End",yrmosNew[-1])
    df["Month"] = [m for m in range(1,13)]
#    print (diffs.head())
    wi = df[(df["Month"] == 1) |  (df["Month"] == 12) | (df["Month"] == 2)]
    sp = df[(df["Month"] == 3) |  (df["Month"] == 4) | (df["Month"] == 5)]
    su = df[(df["Month"] == 6) |  (df["Month"] == 7) | (df["Month"] == 8)]  
    fa = df[(df["Month"] == 9) |  (df["Month"] == 10) | (df["Month"] == 11)]
    summary_df = pd.DataFrame()
    summary_df["City"] = [city]
    summary_df["Var"] = [variable]
    summary_df["Period"] = nperiod
    summary_df["Phase"] = nphase
    summary_df["D-Type"] = dtype
    summary_df["T-Type"] = ttp
    summary_df["Start"] = [yrmosNew[0]]
    summary_df["End"] = [yrmosNew[-1]]
    summary_df["Winter"] = [wi["abs(O-P)/Std"].mean()]
    summary_df["Spring"] = [sp["abs(O-P)/Std"].mean()]
    summary_df["Summer"] = [su["abs(O-P)/Std"].mean()]
    summary_df["Fall"] = [fa["abs(O-P)/Std"].mean()]
    summary_df["R2"] = R2
    print (ttp,summary_df)
    return df,summary_df

# %%
variables = ["TMIN"]
#cities = ["NEW YORK CITY"]
cities = ["DENVER"]
indices = "nina1,nina4,oni,tni"
dtype = 0  #  0 = Actual monthly observations    1 = Monthly anomalies
ttype = 2  #  1 = use Training data for stats    2 = using Testing data for stats
nn=0
nphase=0
nlayers=0
nnodes=0
#nsplit=24
nsplit=0
nperiodStart = 34
nperiodEnd = 36
nperiod = 36
city = "DENVER"
variable = "TMIN"
for nn in range(0,4):
    df_testa,sumry_testa,df_traina,sumry_traina,y_obs,y_pred,cityStats = neuralLSTMT(city,variable,indices,dtype,nphase,nperiod,ttype,nsplit)
    if nn == 0:
        df_test = df_testa
        df_train = df_traina
        sumry_test = sumry_testa
        sumry_train = sumry_traina
    else:
        df_test = df_test.append(df_testa)
        df_train = df_train.append(df_traina)
        sumry_test = sumry_test.append(sumry_testa)
        sumry_train = sumry_train.append(sumry_traina)
#print (df1)
print(sumry_train)
print(sumry_test)

# %%
def trainFB(XX,yy,nsplit,toScale,phase,yrmos,fb):
    ''' create a Train, Test and Experiment datasets out of the input data. If toScale=1, then
    the data will also be scaled.  If toScale=0, the data will not be scaled.  The Experiment 
    time series will be the last nsplit values in the XX and yy lists. The Experiment time series 
    will be used for creating prediction scores'''
    
    info = {}
    info["y_test"] = {}
    info["y_train"] = {}
    ninst = len(yy)  # length of input time series
    yy = yy[phase:]
    yrmosShift = yrmos[phase:]
    XX = XX[0:ninst-phase]
    ntlen=ninst
    ninst = len(yy)  # length of input time series
    print ("LENS ",len(yy),len(XX))
   
    y=yy[0:ninst-nsplit]  #  this will be used to create the Train and Test time sries for the dependant variables
    X=XX[0:ninst-nsplit]  #  this will be used to create the Train and Test time series for the independant variables
    if (nsplit > 0):
        X_exp = XX[ninst-nsplit:]  # create the X experimental dataset for predictions
        y_exp = yy[ninst-nsplit:]  # create the y experimental dataset for predictions
    else:
        X_exp = []
        y_exp = []
    yrmosShift = yrmosShift[0:ninst-nsplit]
    feature_info = ""
    print(ninst,nsplit,ninst-nsplit,len(y_exp))
  #  feature_info = mutual_info_regression(X, y)  #  this can be turned off if you want to look at feature importance
   
   
    nlen = int(len(y)*.8)  # use 80% of data for training
  
#  New method for train and test datea keeps time series togther instead of using random selected points
    if (fb == 1): # Train data from front of TS, testing at back
        X_train = X[:nlen] 
        X_test = X[nlen:] 
        y_train = y[:nlen] 
        y_test = y[nlen:] 
        
        info["y_train"]["start"] = phase
        info["y_train"]["end"] = phase+nlen-1
        info["y_test"]["start"] = phase+nlen
        info["y_test"]["end"] = phase+ninst-nsplit-1
        yrmosTrain = yrmosShift[:nlen]
        yrmosTest = yrmosShift[nlen:]    
    elif (fb == 2): # Train data from end of TS, testing data from front
        nl = len(y) - nlen
        
        X_train = X[nl:] 
        X_test = X[:nl] 
        y_train = y[nl:] 
        y_test = y[:nl] 
        info["y_train"]["start"] = phase+nl
        info["y_train"]["end"] =  phase+len(y)-1
        info["y_test"]["start"] = phase
        info["y_test"]["end"] = phase+nl-1
        yrmosTrain = yrmosShift[nl:]
        yrmosTest = yrmosShift[:nl]
    # create the scaler objects 
    X_scaler = StandardScaler().fit(X_train)
    y_scaler = StandardScaler().fit(y_train)
    if (toScale == 0):  # do not scale data, so return the unsclaled Train,Test and Experiment data
        return (X_train,X_test,X_exp,y_train,y_test,y_exp,feature_info,X_scaler,y_scaler)

    
#  create the scaled Train,Test and Predictio time series for the dependent variable    
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    if (nsplit > 0):
       X_exp_scaled = X_scaler.transform(X_exp)
    else:
       X_exp_scaled = []

#  create the scaled Train,Test and Predictio time series for the independent variable  
    y_train_scaled = y_scaler.transform(y_train)
    y_test_scaled = y_scaler.transform(y_test)
 #   y_exp_scaled = y_scaler.transform(y_exp)

    return (info,yrmosTrain,yrmosTest,X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
            y_test_scaled,y_exp,feature_info,X_scaler,y_scaler,y_train,y_test,nlen,ntlen)

def reshapeTS(ts,nperiod):
    tsnew = []
    nlen = len(ts)
    nfeats = ts.shape[1]
#    traceMsg("start reshape ",nlen,nfeats,ts.shape,ts[0:10])
    for ii in range(nperiod,nlen):
      tmp = []
      for jj in range(0,nfeats):
          hld = []
          for mm in range(ii-nperiod,ii+1):
              hld.append(ts[mm][jj])
          tmp.append(hld)
      tsnew.append(tmp)
    
    tsnew = np.array(tsnew)
#    print("shape ",nperiod,tsnew[0:3])
#    npr = nperiod
    return tsnew




def neuralLSTMTT(y_train,y_test,X_train_scaled,y_train_scaled,X_test_scaled,y_test_scaled,first_neuron,layer):
#  dtype   -  1 = use actual obs   2 = use anaomalies
#  nphase  - amount of the phase shift
#  nperiod - how many time steps to go back in time for each point
#  ttype   - 1 = use Training data for stats   2 = use Test data for stats
    
    
 #   traceMsg("INFO  ",info)
    
   
    #y_train_scaled = [nn for nn in y_train_scaled]
    y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0]))
    y_test_scaled = y_test_scaled.reshape((y_test_scaled.shape[0]))

    y_train_scaled = y_train_scaled[nperiod:]
    y_test_scaled = y_test_scaled[nperiod:]

    X_train_scaled = reshapeTS(X_train_scaled,nperiod)
    X_test_scaled = reshapeTS(X_test_scaled,nperiod)
    if (nsplit > 0):
        X_exp_scaled = reshapeTS(X_exp_scaled,nperiod)
    #y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0], 1, y_train_scaled.shape[1]))
    #X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))

    model = Sequential()
#    model.add(LSTM(50, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
    model.add(LSTM(first_neuron, return_sequences=True,input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
    model.add(LSTM(first_neuron, return_sequences=True))
    model.add(LSTM(first_neuron))
    for nn in range(1,layer+1):
        model.add(Dense(1))
    
    model.compile(loss='mae', optimizer='adam')
        
    history = model.fit(X_train_scaled, y_train_scaled, epochs=50, batch_size=24, validation_data=(X_test_scaled, y_test_scaled), verbose=0, shuffle=False)
   
    # plot history
    print("histroy ",history.history.keys())
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
    if (nsplit > 0):
        y_predict = model.predict(X_exp_scaled)
        y_predict = y_scaler.inverse_transform(y_predict)
    y_train_predict = model.predict(X_train_scaled)
    r2_train = r2_score(y_train_scaled,y_train_predict)

    y_train_predict = y_scaler.inverse_transform(y_train_predict)
    y_train = [mm[0] for mm in y_train]
    y_test = [mm[0] for mm in y_test]
    y_test_predict = model.predict(X_test_scaled)
    r2_test = r2_score(y_test_scaled,y_test_predict)
    print("R2 ",r2_train,r2_test)
    y_test_predict = y_scaler.inverse_transform(y_test_predict)

    
    df_test,summry_test = Stats(2,r2_test,y_test,y_test_predict,yrmosTest[nperiod:],nphase,nperiod,nlen,info,data_checks) 
    df_train,summry_train = Stats(1,r2_train,y_train,y_train_predict,yrmosTrain[nperiod:],nphase,nperiod,nlen,info,data_checks)


    return summry_train,summry_test
                                  
indices = "nina1,nina4,oni,tni"                              
city = "DENVER"
variable = "TMIN"
dtype = 0  #  0 = Actual monthly observations    1 = Monthly anomalies
ttype = 2  #  1 = use Training data for stats    2 = using Testing data for stats
nn=0
nphase=0
nlayers=0
nnodes=0
#nsplit=24
nsplit=0
nperiodStart = 34
nperiodEnd = 36
nperiod = 36
fb = 2   # 1 = Train data come from front of ts, 2 = Train datda come from back of TS


(y,yrs,yrmos,cityStats,cityMeans,cityStds,data_checks) = getData(city,variable,dtype)
X = selectIndices(indices,features,195001,201812,dtype)
traceMsg(X)
print(city,variable)
yy = [nn for nn in y]
(info,yrmosTrain,yrmosTest,X_train_scaled,X_test_scaled,X_exp_scaled,y_train_scaled, \
y_test_scaled,y_exp_scaled,feature_info,X_scaler,y_scaler,y_train,y_test,nlen,ntlen) = \
trainFB(X,yy,nsplit,1,nphase,yrmos,fb)
y_train = y_train[nperiod:]
y_test = y_test[nperiod:]
info["y_train"]["start"]+=nperiod
info["y_test"]["start"]+=nperiod

first_neurons = [25,50,75,100,150]
layers = [1,2,4,6,8,10]
nit = 0

for first_neuron in first_neurons:
    for layer in layers:
        nit+=1
        print (f"--------------  Neurons : {first_neuron}  Layers: {layer}   ------------------")
        sum_trn,sum_tst = neuralLSTMTT(y_train,y_test,X_train_scaled,y_train_scaled,X_test_scaled,y_test_scaled,first_neuron,layer)
        sum_trn = sum_trn.rename(columns = {"R2":"Train R2","Winter":"Train Winter","Spring":"Train Spring","Summer":"Train Summer","Fall":"Train Fall"})
 #       sum_tst = sum_tst.rename({"Winter":"Test Winter","Spring":"Test Spring","Summer":"Test Summer","Fall":"Test Fall"})
      
        summryh = sum_trn
        summryh["Test Winter"] = sum_tst["Winter"]
        summryh["Test Spring"] = sum_tst["Spring"]
        summryh["Test Summer"] = sum_tst["Summer"]
        summryh["Test Fall"] = sum_tst["Fall"]
        summryh["Test R2"] = sum_tst["R2"]
#         summry["Phase"] = nphase
        summryh["Layers"] = layer
        summryh["First_neuron"] = first_neuron
        summryh["FB"] = fb
        if (nit > 1):
            summry = summry.append(summryh)
        else:
            summry = summryh
            
#         summry["City"] = city
print(summry)
summry.to_csv(f"Output/NuerLayer-{city}-{nphase}-{nperiod}-{fb}.csv")
# Out:
#     Var   Obs    Date
# 0  TMIN  13.7  195001
# 1  TMIN  24.6  195002
# 2  TMIN  23.8  195003
# 3  TMIN  33.3  195004
# 4  TMIN  40.3  195005
# nina1
# nina4
# oni
# tni
# (array([[23.01 , 26.94 , -1.53 ,  0.624],
#        [24.32 , 26.67 , -1.34 ,  0.445],
#        [25.11 , 26.52 , -1.16 ,  0.382],
#        ...,
#        [21.18 , 29.71 ,  0.7  , -1.89 ],
#        [22.46 , 29.61 ,  0.85 , -1.734],
#        [23.86 , 29.45 ,  0.82 , -1.7  ]]),)  from  <module>
# DENVER TMIN
# LENS  828 828
# 828 0 828 0
# --------------  Neurons : 25  Layers: 1   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9723319761843127 0.9303166441005818
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.808498
#
#      Spring    Summer      Fall        R2
# 0  1.194164  1.126059  1.163658  0.930317
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.625302
#
#      Spring    Summer      Fall        R2
# 0  0.545603  0.662701  0.645824  0.972332
# --------------  Neurons : 25  Layers: 2   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9649305908348397 0.9080216843789151
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End  Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.7776
#
#      Spring   Summer     Fall        R2
# 0  1.393366  1.51927  1.44034  0.908022
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.666882
#
#      Spring    Summer      Fall        R2
# 0  0.708018  0.756519  0.819717  0.964931
# --------------  Neurons : 25  Layers: 4   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9757050899151377 0.9202764598773988
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.859988
#
#      Spring    Summer      Fall        R2
# 0  1.170671  1.437496  1.272819  0.920276
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.560457
#
#      Spring    Summer      Fall        R2
# 0  0.520433  0.595752  0.649469  0.975705
# --------------  Neurons : 25  Layers: 6   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9713289896610415 0.92769428234559
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.834047
#
#      Spring    Summer      Fall        R2
# 0  1.213411  1.201242  1.303419  0.927694
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.671961
#
#      Spring    Summer      Fall        R2
# 0  0.537017  0.629472  0.607231  0.971329
# --------------  Neurons : 25  Layers: 8   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9705692372306798 0.9223936372992261
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.749926
#
#      Spring    Summer      Fall        R2
# 0  1.098523  1.542237  1.200926  0.922394
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.661854
#
#      Spring    Summer      Fall        R2
# 0  0.538095  0.644461  0.623706  0.970569
# --------------  Neurons : 25  Layers: 10   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9707700051598719 0.932492352016974
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.777384
#
#      Spring    Summer     Fall        R2
# 0  1.093659  1.087701  1.23892  0.932492
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.673843
#
#      Spring    Summer      Fall       R2
# 0  0.457814  0.684326  0.631655  0.97077
# --------------  Neurons : 50  Layers: 1   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9650452481188897 0.9108781823878631
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.866314
#
#      Spring    Summer      Fall        R2
# 0  1.256242  1.431174  1.248373  0.910878
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.798425
#
#      Spring    Summer      Fall        R2
# 0  0.671015  0.664543  0.659953  0.965045
# --------------  Neurons : 50  Layers: 2   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9670380377355068 0.905330193739764
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.797435
#
#      Spring    Summer      Fall       R2
# 0  1.268084  1.641155  1.558346  0.90533
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.671654
#
#      Spring    Summer      Fall        R2
# 0  0.690303  0.823508  0.666586  0.967038
# --------------  Neurons : 50  Layers: 4   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9686365647737528 0.9250353290577008
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.819267
#
#      Spring    Summer      Fall        R2
# 0  1.278815  1.281881  1.240643  0.925035
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.628742
#
#      Spring    Summer     Fall        R2
# 0  0.552198  0.935214  0.62251  0.968637
# --------------  Neurons : 50  Layers: 6   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9691208893755336 0.9308384577137355
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.790698
#
#      Spring    Summer      Fall        R2
# 0  1.135221  1.299115  1.282534  0.930838
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End   Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.62467
#
#     Spring    Summer      Fall        R2
# 0  0.51552  0.864482  0.699813  0.969121
# --------------  Neurons : 50  Layers: 8   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9702233663196865 0.9231747394041968
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  1.014765
#
#      Spring    Summer      Fall        R2
# 0  1.083263  1.278145  1.132966  0.923175
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.753778
#
#      Spring    Summer      Fall        R2
# 0  0.633185  0.599737  0.669673  0.970223
# --------------  Neurons : 50  Layers: 10   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9617055370570984 0.9036582762940208
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.897082
#
#      Spring    Summer      Fall        R2
# 0  1.300666  1.573603  1.461903  0.903658
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.794196
#
#      Spring    Summer      Fall        R2
# 0  0.728859  0.754137  0.796388  0.961706
# --------------  Neurons : 75  Layers: 1   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9674284799608147 0.9272539925439979
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.753402
#
#      Spring    Summer      Fall        R2
# 0  1.197409  1.530193  1.217937  0.927254
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.639244
#
#      Spring    Summer      Fall        R2
# 0  0.835606  0.784756  0.720628  0.967428
# --------------  Neurons : 75  Layers: 2   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9745971278827903 0.9305792199612161
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.816333
#
#      Spring    Summer      Fall        R2
# 0  1.214555  1.255313  1.170974  0.930579
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.604181
#
#      Spring    Summer     Fall        R2
# 0  0.534014  0.665693  0.60013  0.974597
# --------------  Neurons : 75  Layers: 4   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9678878865432967 0.9239618827460586
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.791448
#
#      Spring    Summer      Fall        R2
# 0  1.128839  1.632933  1.217742  0.923962
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.634503
#
#      Spring    Summer      Fall        R2
# 0  0.563916  0.994742  0.755719  0.967888
# --------------  Neurons : 75  Layers: 6   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9660679301844415 0.925817330905873
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.778484
#
#      Spring    Summer      Fall        R2
# 0  1.215308  1.244425  1.343997  0.925817
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.790057
#
#      Spring    Summer      Fall        R2
# 0  0.578621  0.652734  0.714869  0.966068
# --------------  Neurons : 75  Layers: 8   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9690995948659216 0.9068573161532045
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.771637
#
#      Spring    Summer      Fall        R2
# 0  1.259788  1.917051  1.411096  0.906857
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.636869
#
#      Spring    Summer      Fall      R2
# 0  0.537644  1.009264  0.608903  0.9691
# --------------  Neurons : 75  Layers: 10   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.968190554897185 0.9112284155233831
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.767535
#
#      Spring    Summer     Fall        R2
# 0  1.285074  1.632481  1.32997  0.911228
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.648789
#
#      Spring    Summer      Fall        R2
# 0  0.476293  0.814083  0.817066  0.968191
# --------------  Neurons : 100  Layers: 1   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.946322493300927 0.8325171138917042
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  1.368773
#
#      Spring    Summer     Fall        R2
# 0  2.028332  1.874453  1.72981  0.832517
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  1.000862
#
#      Spring    Summer      Fall        R2
# 0  0.907023  1.010264  0.832175  0.946322
# --------------  Neurons : 100  Layers: 2   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9731924566322254 0.9301235860319998
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.808171
#
#      Spring    Summer      Fall        R2
# 0  1.191189  1.241052  1.129773  0.930124
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.605629
#
#      Spring   Summer      Fall        R2
# 0  0.523647  0.71772  0.567254  0.973192
# --------------  Neurons : 100  Layers: 4   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9700078076275671 0.9213494218054077
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.796974
#
#      Spring    Summer     Fall        R2
# 0  1.316763  1.400411  1.20093  0.921349
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.603314
#
#      Spring    Summer      Fall        R2
# 0  0.612919  0.780797  0.731668  0.970008
# --------------  Neurons : 100  Layers: 6   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.941048832670297 0.9035765249918695
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.907352
#
#      Spring    Summer      Fall        R2
# 0  1.058872  2.232915  1.328125  0.903577
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.660265
#
#      Spring    Summer      Fall        R2
# 0  0.606029  2.094991  1.077881  0.941049
# --------------  Neurons : 100  Layers: 8   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9759831929309182 0.9251054671392646
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.822314
#
#      Spring    Summer      Fall        R2
# 0  1.214311  1.395447  1.230547  0.925105
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.615513
#
#      Spring    Summer      Fall        R2
# 0  0.442195  0.559281  0.543756  0.975983
# --------------  Neurons : 100  Layers: 10   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9734465378237761 0.9244314897041103
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.764855
#
#      Spring    Summer      Fall        R2
# 0  1.088756  1.408735  1.210393  0.924431
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.611414
#
#      Spring    Summer      Fall        R2
# 0  0.535435  0.733344  0.667563  0.973447
# --------------  Neurons : 150  Layers: 1   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9557341547745697 0.9045744808259466
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  1.217862
#
#      Spring    Summer      Fall        R2
# 0  1.128628  1.250876  1.376886  0.904574
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  1.053403
#
#      Spring    Summer      Fall        R2
# 0  0.683196  0.606049  0.800791  0.955734
# --------------  Neurons : 150  Layers: 2   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.961309476060591 0.8947900735724018
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  1.112806
#
#     Spring   Summer      Fall       R2
# 0  1.52748  1.49739  1.233497  0.89479
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.923041
#
#      Spring    Summer      Fall        R2
# 0  0.722481  0.655785  0.691432  0.961309
# --------------  Neurons : 150  Layers: 4   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9650144418276099 0.9228665673787714
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End   Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.80082
#
#      Spring    Summer      Fall        R2
# 0  1.306107  1.329131  1.161254  0.922867
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.776459
#
#      Spring    Summer      Fall        R2
# 0  0.597057  0.726818  0.740902  0.965014
# --------------  Neurons : 150  Layers: 6   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9672770262022239 0.9119614937109632
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End   Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.79844
#
#      Spring    Summer      Fall        R2
# 0  1.323476  1.544054  1.386224  0.911961
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End   Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.63204
#
#      Spring   Summer     Fall        R2
# 0  0.672732  0.87567  0.68137  0.967277
# --------------  Neurons : 150  Layers: 8   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.9688766464577943 0.9128573663273638
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.810917
#
#      Spring    Summer     Fall        R2
# 0  1.215425  1.496433  1.45582  0.912857
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End   Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.62367
#
#      Spring    Summer      Fall        R2
# 0  0.669182  0.822311  0.660078  0.968877
# --------------  Neurons : 150  Layers: 10   ------------------
# histroy  dict_keys(['val_loss', 'loss'])
# R2  0.956344361267786 0.914544727375997
# 2      City   Var  Period  Phase  D-Type  T-Type   Start     End  Winter  \
# 0  DENVER  TMIN      36      0       0       2  195301  196310  0.7777
#
#      Spring    Summer      Fall        R2
# 0  1.633777  1.319468  1.290885  0.914545
# 1      City   Var  Period  Phase  D-Type  T-Type   Start     End    Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812  0.830873
#
#      Spring    Summer      Fall        R2
# 0  1.083233  0.666489  0.702353  0.956344
#      City   Var  Period  Phase  D-Type  T-Type   Start     End  Train Winter  \
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.625302
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.666882
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.560457
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.671961
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.661854
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.673843
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.798425
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.671654
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.628742
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.624670
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.753778
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.794196
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.639244
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.604181
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.634503
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.790057
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.636869
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.648789
# 0  DENVER  TMIN      36      0       0       1  196611  201812      1.000862
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.605629
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.603314
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.660265
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.615513
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.611414
# 0  DENVER  TMIN      36      0       0       1  196611  201812      1.053403
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.923041
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.776459
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.632040
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.623670
# 0  DENVER  TMIN      36      0       0       1  196611  201812      0.830873
#
#    Train Spring  ...  Train Fall  Train R2  Test Winter  Test Spring  \
# 0      0.545603  ...    0.645824  0.972332     0.808498     1.194164
# 0      0.708018  ...    0.819717  0.964931     0.777600     1.393366
# 0      0.520433  ...    0.649469  0.975705     0.859988     1.170671
# 0      0.537017  ...    0.607231  0.971329     0.834047     1.213411
# 0      0.538095  ...    0.623706  0.970569     0.749926     1.098523
# 0      0.457814  ...    0.631655  0.970770     0.777384     1.093659
# 0      0.671015  ...    0.659953  0.965045     0.866314     1.256242
# 0      0.690303  ...    0.666586  0.967038     0.797435     1.268084
# 0      0.552198  ...    0.622510  0.968637     0.819267     1.278815
# 0      0.515520  ...    0.699813  0.969121     0.790698     1.135221
# 0      0.633185  ...    0.669673  0.970223     1.014765     1.083263
# 0      0.728859  ...    0.796388  0.961706     0.897082     1.300666
# 0      0.835606  ...    0.720628  0.967428     0.753402     1.197409
# 0      0.534014  ...    0.600130  0.974597     0.816333     1.214555
# 0      0.563916  ...    0.755719  0.967888     0.791448     1.128839
# 0      0.578621  ...    0.714869  0.966068     0.778484     1.215308
# 0      0.537644  ...    0.608903  0.969100     0.771637     1.259788
# 0      0.476293  ...    0.817066  0.968191     0.767535     1.285074
# 0      0.907023  ...    0.832175  0.946322     1.368773     2.028332
# 0      0.523647  ...    0.567254  0.973192     0.808171     1.191189
# 0      0.612919  ...    0.731668  0.970008     0.796974     1.316763
# 0      0.606029  ...    1.077881  0.941049     0.907352     1.058872
# 0      0.442195  ...    0.543756  0.975983     0.822314     1.214311
# 0      0.535435  ...    0.667563  0.973447     0.764855     1.088756
# 0      0.683196  ...    0.800791  0.955734     1.217862     1.128628
# 0      0.722481  ...    0.691432  0.961309     1.112806     1.527480
# 0      0.597057  ...    0.740902  0.965014     0.800820     1.306107
# 0      0.672732  ...    0.681370  0.967277     0.798440     1.323476
# 0      0.669182  ...    0.660078  0.968877     0.810917     1.215425
# 0      1.083233  ...    0.702353  0.956344     0.777700     1.633777
#
#    Test Summer  Test Fall   Test R2  Layers  First_neuron  FB
# 0     1.126059   1.163658  0.930317       1            25   2
# 0     1.519270   1.440340  0.908022       2            25   2
# 0     1.437496   1.272819  0.920276       4            25   2
# 0     1.201242   1.303419  0.927694       6            25   2
# 0     1.542237   1.200926  0.922394       8            25   2
# 0     1.087701   1.238920  0.932492      10            25   2
# 0     1.431174   1.248373  0.910878       1            50   2
# 0     1.641155   1.558346  0.905330       2            50   2
# 0     1.281881   1.240643  0.925035       4            50   2
# 0     1.299115   1.282534  0.930838       6            50   2
# 0     1.278145   1.132966  0.923175       8            50   2
# 0     1.573603   1.461903  0.903658      10            50   2
# 0     1.530193   1.217937  0.927254       1            75   2
# 0     1.255313   1.170974  0.930579       2            75   2
# 0     1.632933   1.217742  0.923962       4            75   2
# 0     1.244425   1.343997  0.925817       6            75   2
# 0     1.917051   1.411096  0.906857       8            75   2
# 0     1.632481   1.329970  0.911228      10            75   2
# 0     1.874453   1.729810  0.832517       1           100   2
# 0     1.241052   1.129773  0.930124       2           100   2
# 0     1.400411   1.200930  0.921349       4           100   2
# 0     2.232915   1.328125  0.903577       6           100   2
# 0     1.395447   1.230547  0.925105       8           100   2
# 0     1.408735   1.210393  0.924431      10           100   2
# 0     1.250876   1.376886  0.904574       1           150   2
# 0     1.497390   1.233497  0.894790       2           150   2
# 0     1.329131   1.161254  0.922867       4           150   2
# 0     1.544054   1.386224  0.911961       6           150   2
# 0     1.496433   1.455820  0.912857       8           150   2
# 0     1.319468   1.290885  0.914545      10           150   2
#
# [30 rows x 21 columns]
